# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel (r'/Users/faaizahdesai/Desktop/City1.xlsx', sheet_name = 'City1')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
Term_Start1 = df.set_index('Term_Start').sort_values(by = 'Term_Start')

# %%
TTS = Term_Start1.sort_values(by = ['Term_Start','Turnout','Polls_Close'])

# %%
ci = df.set_index('CityID').sort_values(by = ['CityID','Term_Start'])

# %%
cii = pd.DataFrame(ci, columns = (['Term_Start']))

# %%
cii.stack()
# Out:
# CityID
# 0       Term_Start   1902-01-01
#         Term_Start   1902-01-01
#         Term_Start   1902-01-01
#         Term_Start   1902-01-01
#         Term_Start   1902-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1904-01-01
#         Term_Start   1906-01-01
#         Term_Start   1906-01-01
#         Term_Start   1906-01-01
#         Term_Start   1906-01-01
#         Term_Start   1906-01-01
#         Term_Start   1906-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1910-01-01
#         Term_Start   1914-01-01
#         Term_Start   1914-01-01
#         Term_Start   1914-01-01
# ...

# %%
TTS.stack()
# Out:
# Term_Start
# 1900-01-01  CityID                          22
#             CandID                      262151
#             Polls_Close    1899-12-12 00:00:00
#             Share                        50.21
#             Turnout                      18.14
#             CityID                          22
#             CandID                      262149
#             Polls_Close    1899-12-12 00:00:00
#             Share                         47.4
#             Turnout                      18.14
#             CityID                          22
#             CandID                      262156
#             Polls_Close    1899-12-12 00:00:00
#             Share                          1.2
#             Turnout                      18.14
#             CityID                          22
#             CandID                      104521
#             Polls_Close    1899-12-12 00:00:00
#             Share                         1.19
#             Turnout                      18.14
# ...
